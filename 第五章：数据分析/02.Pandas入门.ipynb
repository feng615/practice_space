# %%
import pandas as pd

df = pd.DataFrame([
    {"姓名": "张三", "语文": 78, "英语": 65, "数学": 89},
    {"姓名": "李四", "语文": 68, "英语": 75, "数学": 79},
    {"姓名": "王五", "语文": 88, "英语": 85, "数学": 99},
    {"姓名": "赵六", "语文": 98, "英语": 95, "数学": 89},
    {"姓名": "孙七", "语文": 78, "英语": 65, "数学": 89},
    {"姓名": "周八", "语文": 68, "英语": 75, "数学": 79},
    {"姓名": "吴九", "语文": 88, "英语": 85, "数学": 99}
])

print(f"语文最高分：{df['语文'].max()}, 最低分：{df['语文'].min()}, 平均分：{df['语文'].mean():.2f}")
print(f"英语最高分：{df['英语'].max()}, 最低分：{df['英语'].min()}, 平均分：{df['英语'].mean():.2f}")
print(f"数学最高分：{df['数学'].max()}, 最低分：{df['数学'].min()}, 平均分：{df['数学'].mean():.2f}")
# Out:
# 语文最高分：98, 最低分：68, 平均分：80.86
# 英语最高分：95, 最低分：65, 平均分：77.86
# 数学最高分：99, 最低分：79, 平均分：89.00
